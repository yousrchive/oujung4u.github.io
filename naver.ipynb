# %%
#키 모음
# V_nYKHysuvrECXKayiOY
# widIdEMNm7

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pyautogui

client_id = "V_nYKHysuvrECXKayiOY"
client_secret = "widIdEMNm7"

#검색어 입력 창
keyword = pyautogui.prompt("검색어를 입력하세요.")
encText = urllib.parse.quote(keyword)

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 11 Jan 2024 16:03:13 +0900",
# 	"total":11038577,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"풍미 넘쳤던 <b>제주도<\/b> 고기집",
# 			"link":"https:\/\/blog.naver.com\/ssanga85\/223285758253",
# 			"description":"친척들과 방문했던 <b>제주도<\/b>에서 이틀 날 들렸던 <b>제주도<\/b> 고기집을 소개해 보려고 해요. 마블링이나 육즙이 가득해서 쫄깃하고 고소한 풍미를 한껏 누릴 수 있는 곳이었죠. 탑부평 본점 주소 : 제주 제주시... ",
# 			"bloggername":"S2 덩이의긍정적우주별☆",
# 			"bloggerlink":"blog.naver.com\/ssanga85",
# 			"postdate":"20231207"
# 		},
# 		{
# 			"title":"기대이상으로 맛깔났던 <b>제주도<\/b> 고기집",
# 			"link":"https:\/\/blog.naver.com\/manpwup\/223309990226",
# 			"description":"지난달에는 가족들이랑 제주로 놀러갔다가 현지인들에게도 인기있는 <b>제주도<\/b> 고기집이 있다고해서... 게다가 <b>제주도<\/b> 고기집은 고기와 같이 먹을 수 있는 반찬들은 언제든 가져다 먹을 수 있도록 셀프바에 있었고... ",
# 			"bloggername":"ㅋ.ㅋ",
# 			"bloggerlink":"blog.naver.com\/manpwup",
# 			"postdate":"20240102"
# 		},
# 		{
# 			"title":"<b>제주도<\/b> 공항근처 맛집 흑돼지 원탑 제주고집",
# 			"link":"https:\/\/blog.naver.com\/sangil00\/223317388040",
# 			"description":"친구들과 떠난 신년 휴가에서도 수소문해 찾아둔 <b>제주도<\/b> 공항근처 맛집에서 부드러운 육질을 만끽하고... 매장 내부로 입장하자마자 <b>제주도<\/b> 공항근처 맛집의 넓은 홀을 마주할 수 있었어요. 좌석 간격도 널찍한... ",
# 			"bloggername":"길을 찾는 즐거움_거칠부",
# 			"bloggerlink":"blog.naver.com\/sangil00",
# 			"postdate":"20240109"
# 		},
# 		{
# 			"title":"제주 일주일 살기 <b>제주도<\/b> 렌트카 가격비교 사이트 카모아 추천... ",
# 			"link":"https:\/\/blog.naver.com\/123goodgood\/223318142037",
# 			"description":"제주 여행 일주일 살기 <b>제주도<\/b> 렌트카 여행 안녕하세요, 숩숩이에요! 제주 여행 일주일 살기 누구나 한 번쯤 생각하실텐데요. 저는 <b>제주도<\/b> 일주일 살기 꿈을 실현하며 일주일 간 교통수단을 어떻게 할지 고민을... ",
# 			"bloggername":"숩숩의 감성 여행기",
# 			"bloggerlink":"blog.naver.com\/123goodgood",
# 			"postdate":"20240110"
# 		},
# 		{
# 			"title":"토요일은 밥이 좋아 제주 먹돌 본점 토밥 <b>제주도<\/b>편 고기국수... ",
# 			"link":"https:\/\/blog.naver.com\/bahnsoon\/223316276682",
# 			"description":"지난 주에 <b>제주도<\/b>에 거주하는 친구를 만나러 가서 인기있는 토요일은 밥이 좋아 제주편 고기국수... 토밥 <b>제주도<\/b> 맛집은 고기국수는 물론 평소 쉽게 접해보지 못한 지역 특색을 살린 다양한 먹거리가 소개되어... ",
# 			"bloggername":"bahnd'Arc In Wonderland",
# 			"bloggerlink":"blog.naver.com\/bahnsoon",
# 			"postdate":"20240108"
# 		},
# 		{
# 			"title":"토요일은 밥이좋아 <b>제주도<\/b> 함덕 갈치구이 맛집 계절식탁",
# 			"link":"https:\/\/blog.naver.com\/hyo761\/223316318922",
# 			"description":"어제 친구와 토요일은 밥이좋아 <b>제주도<\/b> 편을 보고 바로 먹으러 다녀왔는데요. 함덕 갈치구이와... 위생 관리도 철처하게 하는 식당이라 토요일은 밥이좋아 <b>제주도<\/b> 에 나온 그대로였답니다. 원산지 표시판도... ",
# 			"bloggername":"행복바이러스",
# 			"bloggerlink":"blog.naver.com\/hyo761",
# 			"postdate":"20240108"
# 		},
# 		{
# 			"title":"뜻깊은 <b>제주도<\/b> 갈치구이 맛집",
# 			"link":"https:\/\/blog.naver.com\/yoolong2412\/223312232932",
# 			"description":"오랜만에 친구들과 떠난 여행 중 가보고 싶던 <b>제주도<\/b> 갈치구이 맛집에 방문했어요. 싱싱한 갈치로 만든... 나오는 <b>제주도<\/b> 갈치구이 맛집이었어요. 먹을때 아삭한 소리가 들릴만큼 파릇파릇한 질감이... ",
# 			"bloggername":"요롱이의 테이블 일지",
# 			"bloggerlink":"blog.naver.com\/yoolong2412",
# 			"postdate":"20240104"
# 		},
# 		{
# 			"title":"노포 감성 <b>제주도<\/b> 로컬 맛집 노도",
# 			"link":"https:\/\/blog.naver.com\/kjin4001\/223305562868",
# 			"description":"얼마 전에 친구들과 용담해안 도로에서 드라이브를 하다가 <b>제주도<\/b> 로컬 맛집에서 식사를 했는데요.... <b>제주도<\/b> 로컬 맛집 회랑도 잘 어울릴만한 술이라고 생각했어요. 곧 메뉴판을 펼쳐들고는 읽어 보기... ",
# 			"bloggername":"그래그래마녀의 해피하우스",
# 			"bloggerlink":"blog.naver.com\/kjin4001",
# 			"postdate":"20231228"
# 		},
# 		{
# 			"title":"혼자 알기 아까운 <b>제주도<\/b> 시내 맛집",
# 			"link":"https:\/\/blog.naver.com\/ppozogae\/223282689982",
# 			"description":"이번엔 얼마전 다녀온 <b>제주도<\/b> 여행에서 잊지 못할 맛을 보았던 <b>제주도<\/b> 시내 맛집을 소개해드릴 건데요. 체중증가는 생각지도 않고 정신없이 먹었던 것 같아요. 탑부평 본점 주소 : 제주 제주시 관덕로15길 26... ",
# 			"bloggername":"제라쌤의 하루",
# 			"bloggerlink":"blog.naver.com\/ppozogae",
# 			"postdate":"20231204"
# 		},
# 		{
# 			"title":"토요일은 밥이좋아 제주 고등어회 맛집 토밥즈 <b>제주도<\/b> 계절식탁",
# 			"link":"https:\/\/blog.naver.com\/jinju1469\/223313530296",
# 			"description":"얼마 전 지인이 사는 <b>제주도<\/b>에 놀러가 토요일은 밥이좋아 제주편으로 나왔던 곳에 다녀왔어요.... 토밥즈 <b>제주도<\/b>에 나온 그대로라 실제로 보면 더 푸짐함이 느껴지더라고요. 밑반찬으로 나온 새우장은... ",
# 			"bloggername":"delight",
# 			"bloggerlink":"blog.naver.com\/jinju1469",
# 			"postdate":"20240105"
# 		}
# 	]
# }

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pyautogui
import pandas as pd
import re
import json

client_id = "V_nYKHysuvrECXKayiOY"
client_secret = "widIdEMNm7"

query = urllib.parse.quote(input("검색질의: "))
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
    
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText \
        + "&display=" + str(display) \
        + "&start=" + str(start_index)
        
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        web_df.loc[idx] = [title, link, description]
        idx += 1
    else:
        print("Error Code:" + str(rescode))
        
web_df
# Out:
# Error Code:200
#                                      Title  \
# 0                크리스마스에 서울에서 가볼만한 축제를 찾아보자
# 1        서울 대표 일출 명소 응봉산 해맞이 축제 2024, 기본정보
# 2                  외국인서울관광 장소추천, 광장시장맛집 추천
# 3                  서울무릎병원 퇴행성관절염 비수술로 치료하는
# 4   [도원스타일 서울역] 깔끔 고급 맛있는 중식 레스토랑 연말모임...
# ..                                     ...
# 95                 광화문 2023 서울빛초롱축제 서울 라이트
# 96          서울 강서구 마곡 크리스마스로 유명한 카페 어나더사이드
# 97              20일차 새벽기상_서울 전세 상승, 추신수 은퇴
# 98        2024 새해 카운트다운 서울 제야의 종 행사 자정의 태양
# 99       #약수역 카페_ 감각적인 오버트 서울 커피(동대입구역 근처)
#
#                                                 Link  \
# 0               https://withbeatles.tistory.com/8324
# 1     https://blog.naver.com/blackcatgo/223305300741
# 2      https://blog.naver.com/amukannah/223309554159
# 3      https://blog.naver.com/tjrxkq123/223304982680
# 4         https://blog.naver.com/yr1109/223304238813
# ..                                               ...
# 95    https://blog.naver.com/jylhee0704/223295080953
# 96  https://blog.naver.com/queeny_rella/223301119563
# 97      https://blog.naver.com/puriri07/223293967235
# 98   https://blog.naver.com/waxcatansan/223299730590
# 99       https://blog.naver.com/euirime/223299851258
#
#                                           Description
# 0   크리스마스에 서울에서 가볼만한곳을 살펴보고 즐거운 크리스마스를 계획해보자. 서울 크...
# 1   서울 대표 일출 명소 서울 성동구 응봉산 팔각정에서 '2024년 갑진년 응봉산 해맞...
# 2   서울 외국인관광 장소추천 1. 경복궁 / 덕수궁 - 날씨가 좋다면, 경복궁이나 덕수...
# 3   서울무릎병원은 &quot;자가 골수 줄기세포 주사 치료법이 관절 염증 통증 완화 그...
# 4   도원스타일 서울역 방문 도원스타일 서울역점 서울역 모임맛집 고급 중식 레스토랑 연말...
# ..                                                ...
# 95  광화문광장에서 크리스마스 마켓도 열리고 2023 서울빛초롱축제 서울 라이트도 열리고...
# 96  Q u e e n y [Queeny_퀴니] #어나더사이드 #강서카페 #마곡카페 #서...
# 97  서울전세 신고가 전셋값 30주 연속 상승세 매일경제 역전세 문제로 서울집이 싸게 나...
# 98  연말 동안 이어지는 서울 윈터 페스타 WINTA의 제야의 종 타종행사 세종로 '자정...
# 99  약수역 카페_ 감각적인 오버트 서울(커피 원두 선택가능) 안녕하세요 키호입니다. 블...
#
# [100 rows x 3 columns]

# %%
# 네이버 검색 API 예제 - 지식인 검색
import os
import sys
import urllib.request
import pyautogui
import pandas as pd
import re
import json

client_id = "V_nYKHysuvrECXKayiOY"
client_secret = "widIdEMNm7"

encText = urllib.parse.quote(pyautogui.prompt("검색어를 입력하세요."))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
    
    url = "https://openapi.naver.com/v1/search/kin?query=" + encText \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort
    
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        kin_df.loc[idx] = [title, link, description]
        idx += 1
    else:
        print("Error Code:" + str(rescode))
        
kin_df

#여기 딱 키워드가 정확히 들어있을 때만 가져오면 좋을 듯
# Out:
# Error Code:200
#                       Title  \
# 0   제주도 3박4일 가족여행코스 일정질문 ㅠㅠ
# 1              2박3일 제주도여행코스
# 2    겨울 제주도 여행 2박3일 코스좀짜주세용
# 3      화요일에 제주 여행가는데요 제주사시는
# 4          제주도 코스좀 ㅠㅠ 도와주세요
# ..                      ...
# 95         12월 제주도여행코스 추천!!
# 96     제주도로 부모님과 할머니 할아버지 모
# 97         제주도여행 2박 3일 여행일정
# 98     금요일 9시 제주공항도착 일요일 오후
# 99      제주도 4박5일 여행코스짜주세요ㅠㅠ
#
#                                                  Link  \
# 0   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 1   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 2   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 3   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 4   https://kin.naver.com/qna/detail.naver?d1id=9&...
# ..                                                ...
# 95  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 96  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 97  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 98  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 99  https://kin.naver.com/qna/detail.naver?d1id=12...
#
#                                           Description
# 0   ... 그리고 2일날아침에 한라산등반을 예정이구요 .첫날엔 서부쪽 (오설록....등...
# 1   ... 운전을 못해서 버스를 타고 여행을 해야하는데 카멜리아힐,오설록... 제주도 ...
# 2   ... 트릭아트도 가보고싶습니다 오설록!!도 넣어주세요 알차게 놀고... - 가고자...
# 3   ... 오설록 지금 겨울인데멀쩡한지잎파리 ㅋ;; 가족끼리여행가는거라 ㅠㅠ 답변 여행...
# 4   ... 월욜밤 9시10비행기요 카멜리아힐 산방산 알작지 오설록 휴애리 쇠소깍 서귀포...
# ..                                                ...
# 95  ... 한화아쿠아플라넷포함 소인국테마파크,박물관은살아있다,에코랜드,김녕미로공원,러브...
# 96  ... 선녀와나무꾼 .오설록.아쿠아 플라리넷.섭지코지등 넣어서 2박3일 코스좀 추전...
# 97  ... 협재해수욕장, 오설록 등등입니다~ 차도없고 멘붕~~~~~~ 도와주세요 여러뷴...
# 98  ... 오설록 소인국 초콜릿박물관 에코랜드 성산일출봉 천지연폭포..정도이구요.. 가...
# 99  ... 대충 중문관광단지 / 대포주상절리 / 카멜리아힐 / 오설록 / 협제해수욕장 ...
#
# [100 rows x 3 columns]
