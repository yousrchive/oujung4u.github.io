# %%
#키 모음
# 클라이언트아이다
# 클라이언트시크릿릿

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pyautogui

client_id = "클라이언트아이디"
client_secret = "클라이언트시크릿"

keyword = pyautogui.prompt("검색어를 입력하세요.")
encText = urllib.parse.quote(keyword)

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       8 client_secret = "widIdEMNm7"
#      10 keyword = pyautogui.prompt("검색어를 입력하세요.")
# ---> 11 encText = urllib.parse.quote(keyword)
#      13 url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
#      14 # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
#
# File c:\Users\Playdata\AppData\Local\Programs\Python\Python311\Lib\urllib\parse.py:893, in quote(string, safe, encoding, errors)
#     891     if errors is not None:
#     892         raise TypeError("quote() doesn't support 'errors' for bytes")
# --> 893 return quote_from_bytes(string, safe)
#
# File c:\Users\Playdata\AppData\Local\Programs\Python\Python311\Lib\urllib\parse.py:923, in quote_from_bytes(bs, safe)
#     918 """Like quote(), but accepts a bytes object rather than a str, and does
#     919 not perform string-to-bytes encoding.  It always returns an ASCII string.
#     920 quote_from_bytes(b'abc def\x3f') -> 'abc%20def%3f'
#     921 """
#     922 if not isinstance(bs, (bytes, bytearray)):
# --> 923     raise TypeError("quote_from_bytes() expected bytes")
#     924 if not bs:
#     925     return ''
#
# TypeError: quote_from_bytes() expected bytes

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pyautogui
import pandas as pd
import re
import json

client_id = "클라이언트아이디"
client_secret = "클라이언트시크릿릿"

query = urllib.parse.quote(input("검색질의: "))
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
    
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText \
        + "&display=" + str(display) \
        + "&start=" + str(start_index)
        
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        web_df.loc[idx] = [title, link, description]
        idx += 1
    else:
        print("Error Code:" + str(rescode))
        
web_df
# Out:
# Error Code:200
#                                      Title  \
# 0                크리스마스에 서울에서 가볼만한 축제를 찾아보자
# 1        서울 대표 일출 명소 응봉산 해맞이 축제 2024, 기본정보
# 2                  외국인서울관광 장소추천, 광장시장맛집 추천
# 3                  서울무릎병원 퇴행성관절염 비수술로 치료하는
# 4   [도원스타일 서울역] 깔끔 고급 맛있는 중식 레스토랑 연말모임...
# ..                                     ...
# 95                 광화문 2023 서울빛초롱축제 서울 라이트
# 96          서울 강서구 마곡 크리스마스로 유명한 카페 어나더사이드
# 97              20일차 새벽기상_서울 전세 상승, 추신수 은퇴
# 98        2024 새해 카운트다운 서울 제야의 종 행사 자정의 태양
# 99       #약수역 카페_ 감각적인 오버트 서울 커피(동대입구역 근처)
#
#                                                 Link  \
# 0               https://withbeatles.tistory.com/8324
# 1     https://blog.naver.com/blackcatgo/223305300741
# 2      https://blog.naver.com/amukannah/223309554159
# 3      https://blog.naver.com/tjrxkq123/223304982680
# 4         https://blog.naver.com/yr1109/223304238813
# ..                                               ...
# 95    https://blog.naver.com/jylhee0704/223295080953
# 96  https://blog.naver.com/queeny_rella/223301119563
# 97      https://blog.naver.com/puriri07/223293967235
# 98   https://blog.naver.com/waxcatansan/223299730590
# 99       https://blog.naver.com/euirime/223299851258
#
#                                           Description
# 0   크리스마스에 서울에서 가볼만한곳을 살펴보고 즐거운 크리스마스를 계획해보자. 서울 크...
# 1   서울 대표 일출 명소 서울 성동구 응봉산 팔각정에서 '2024년 갑진년 응봉산 해맞...
# 2   서울 외국인관광 장소추천 1. 경복궁 / 덕수궁 - 날씨가 좋다면, 경복궁이나 덕수...
# 3   서울무릎병원은 &quot;자가 골수 줄기세포 주사 치료법이 관절 염증 통증 완화 그...
# 4   도원스타일 서울역 방문 도원스타일 서울역점 서울역 모임맛집 고급 중식 레스토랑 연말...
# ..                                                ...
# 95  광화문광장에서 크리스마스 마켓도 열리고 2023 서울빛초롱축제 서울 라이트도 열리고...
# 96  Q u e e n y [Queeny_퀴니] #어나더사이드 #강서카페 #마곡카페 #서...
# 97  서울전세 신고가 전셋값 30주 연속 상승세 매일경제 역전세 문제로 서울집이 싸게 나...
# 98  연말 동안 이어지는 서울 윈터 페스타 WINTA의 제야의 종 타종행사 세종로 '자정...
# 99  약수역 카페_ 감각적인 오버트 서울(커피 원두 선택가능) 안녕하세요 키호입니다. 블...
#
# [100 rows x 3 columns]

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pyautogui
import pandas as pd
import re
import json

client_id = "클라이언트아이디"
client_secret = "클라이언트시크릿릿"

encText = urllib.parse.quote(pyautogui.prompt("검색어를 입력하세요."))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
    
    url = "https://openapi.naver.com/v1/search/kin?query=" + encText \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort
    
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        kin_df.loc[idx] = [title, link, description]
        idx += 1
    else:
        print("Error Code:" + str(rescode))
        
kin_df
# Out:
# Error Code:200
#                       Title  \
# 0   제주도 3박4일 가족여행코스 일정질문 ㅠㅠ
# 1              2박3일 제주도여행코스
# 2    겨울 제주도 여행 2박3일 코스좀짜주세용
# 3      화요일에 제주 여행가는데요 제주사시는
# 4          제주도 코스좀 ㅠㅠ 도와주세요
# ..                      ...
# 95         12월 제주도여행코스 추천!!
# 96     제주도로 부모님과 할머니 할아버지 모
# 97         제주도여행 2박 3일 여행일정
# 98     금요일 9시 제주공항도착 일요일 오후
# 99      제주도 4박5일 여행코스짜주세요ㅠㅠ
#
#                                                  Link  \
# 0   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 1   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 2   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 3   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 4   https://kin.naver.com/qna/detail.naver?d1id=9&...
# ..                                                ...
# 95  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 96  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 97  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 98  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 99  https://kin.naver.com/qna/detail.naver?d1id=12...
#
#                                           Description
# 0   ... 그리고 2일날아침에 한라산등반을 예정이구요 .첫날엔 서부쪽 (오설록....등...
# 1   ... 운전을 못해서 버스를 타고 여행을 해야하는데 카멜리아힐,오설록... 제주도 ...
# 2   ... 트릭아트도 가보고싶습니다 오설록!!도 넣어주세요 알차게 놀고... - 가고자...
# 3   ... 오설록 지금 겨울인데멀쩡한지잎파리 ㅋ;; 가족끼리여행가는거라 ㅠㅠ 답변 여행...
# 4   ... 월욜밤 9시10비행기요 카멜리아힐 산방산 알작지 오설록 휴애리 쇠소깍 서귀포...
# ..                                                ...
# 95  ... 한화아쿠아플라넷포함 소인국테마파크,박물관은살아있다,에코랜드,김녕미로공원,러브...
# 96  ... 선녀와나무꾼 .오설록.아쿠아 플라리넷.섭지코지등 넣어서 2박3일 코스좀 추전...
# 97  ... 협재해수욕장, 오설록 등등입니다~ 차도없고 멘붕~~~~~~ 도와주세요 여러뷴...
# 98  ... 오설록 소인국 초콜릿박물관 에코랜드 성산일출봉 천지연폭포..정도이구요.. 가...
# 99  ... 대충 중문관광단지 / 대포주상절리 / 카멜리아힐 / 오설록 / 협제해수욕장 ...
#
# [100 rows x 3 columns]

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pyautogui
import pandas as pd
import re
import json

client_id = "클라이언트아이디"
client_secret = "클라이언트시크릿릿"

encText = urllib.parse.quote(pyautogui.prompt("검색어를 입력하세요."))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
    
    url = "https://openapi.naver.com/v1/search/kin?query=" + encText \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort
    
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        kin_df.loc[idx] = [title, link, description]
        idx += 1
    else:
        print("Error Code:" + str(rescode))
        
kin_df
